# %%
# 1. Use beutifulsoup to 
# 2. Confirm loaded correctly
# 3. define def to find the table
# what does it return the table as? 

import pandas as pd
from bs4 import BeautifulSoup as bs

def getTables(htmlDoc):
	with open(htmlDoc) as fp:
		soup = bs(fp)
	return soup.findAll('table')
	
course_hist = getTables('course_history.html')

print(course_hist)
# Out:
# [<table width="800px"><tbody><tr><td colspan="2"><p>Undergraduate Credential Summary </p><br/></td></tr><tr><td class="t1">Credential Awarded: </td><td>Bachelor of Arts</td></tr><tr><td class="t1">Plan: </td><td>Specialization Pure and Applied Mathematics</td></tr><tr><td class="t1">Confer Date: </td><td>05/10/2018</td></tr><tr><td class="t1">Final Graduation GPA: </td><td> 3.21</td></tr><tr><td colspan="2"><br/><br/></td></tr><tr><td colspan="2"><p>Undergraduate Academic Program History </p></td></tr><tr><td colspan="2"><br/></td></tr><tr><td class="t1">Active in Program</td><td>26/08/2015</td></tr><tr><td class="t1">Admit Term </td><td>Fall 2015</td></tr><tr><td class="t1"> </td><td>Matriculated</td></tr><tr><td class="t1"> </td><td>Bachelor of Arts</td></tr><tr><td class="t1"> </td><td>Major Mathematics and Statistics</td></tr><tr><td colspan="2"><br/></td></tr><tr><td class="t1">Active in Program</td><td>30/11/2015</td></tr><tr><td class="t1"> </td><td>Concentration Change</td></tr><tr><td class="t1"> </td><td>Bachelor of Arts</td></tr><tr><td class="t1"> </td><td>Specialization Pure and Applied Mathematics</td></tr><tr><td colspan="2"><br/></td></tr><tr><td class="t1">Completed Program</td><td>15/10/2018</td></tr><tr><td class="t1"> </td><td>Program Completed</td></tr><tr><td class="t1"> </td><td>Bachelor of Arts</td></tr><tr><td class="t1"> </td><td>Specialization Pure and Applied Mathematics</td></tr><tr><td class="t1">Min. Credits Required:</td><td>90.00</td></tr><tr><td class="t1">Program Credits Earned:</td><td>105.50</td></tr><tr><td class="t1">Cumulative GPA:</td><td> 3.21</td></tr><tr><td colspan="2"><br/><br/></td></tr><tr><td colspan="2"><p>Beginning of Undergraduate Record </p></td></tr><tr><td colspan="2"><br/></td></tr><tr><td colspan="2"><b>Fall 2015</b></td></tr><tr><td colspan="2">Bachelor of Arts, Specialization Pure and Applied Mathematics</td></tr><tr><td class="crsTBH" colspan="3">Transfer Credits</td></tr><tr><td colspan="2"><table border="0" class="crsTB"><tbody><tr><th class="tc1" colspan="2">Course</th><th class="tc2">Description</th><th class="tc3">Grade</th><th class="tc4">Year Attended</th><th class="tc5">Program Credits Earned</th></tr><tr><td class="tc11">GENL</td><td class="tc12">    AB</td><td class="tc2">McGill University 1997-2002</td><td class="tc3">TRC</td><td class="tc4">2002</td><td class="tc5">30.00</td></tr></tbody></table></td></tr><tr><td colspan="2"> </td></tr><tr><td class="crsTBH" colspan="3">Transfer Credits</td></tr><tr><td colspan="2"><table border="0" class="crsTB"><tbody><tr><th class="tc1" colspan="2">Course</th><th class="tc2">Description</th><th class="tc3">Grade</th><th class="tc4">Year Attended</th><th class="tc5">Program Credits Earned</th></tr><tr><td class="tc11">MAST</td><td class="tc12"> 218</td><td class="tc2">Langara College 2003-05</td><td class="tc3">TRC</td><td class="tc4">2005</td><td class="tc5"> 3.00</td></tr><tr><td class="tc11">MAST</td><td class="tc12"> 234</td><td class="tc2">Langara College 2003-05</td><td class="tc3">TRC</td><td class="tc4">2005</td><td class="tc5"> 3.00</td></tr><tr><td class="tc11">MATH</td><td class="tc12"> 201</td><td class="tc2">Langara College 2003-05</td><td class="tc3">EX</td><td class="tc4">2005</td><td class="tc5"> 0.00</td></tr><tr><td class="tc11">MATH</td><td class="tc12"> 203</td><td class="tc2">Langara College 2003-05</td><td class="tc3">EX</td><td class="tc4">2005</td><td class="tc5"> 0.00</td></tr><tr><td class="tc11">MATH</td><td class="tc12"> 204</td><td class="tc2">Langara College 2003-05</td><td class="tc3">EX</td><td class="tc4">2005</td><td class="tc5"> 0.00</td></tr><tr><td class="tc11">MATH</td><td class="tc12"> 205</td><td class="tc2">Langara College 2003-05</td><td class="tc3">EX</td><td class="tc4">2005</td><td class="tc5"> 0.00</td></tr><tr><td class="tc11">MATH</td><td class="tc12"> 206</td><td class="tc2">Langara College 2003-05</td><td class="tc3">EX</td><td class="tc4">2005</td><td class="tc5"> 0.00</ ...

# %% [markdown]
# But all this does is find the table enclosed in the `table` tag. I want to get rid of all that and have what's in the cells.
#
# Try Pandas next

# %%
col_names = ['Course', 'Num','Section',	'Description',	
             'Attempted','Grade','Notation',	
             'GPA','Class Avg',	'Class Size',	
             'Credits Earned','Other']
len(col_names)
# Out:
# 13

# %%
df_list = pd.read_html('course_history.html')

for i, df in enumerate(df_list):
    print(df)
    df.to_csv('table {}.csv'.format(i))
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-12-eddfbe4b1618> in <module>()
# ----> 1 df_list = pd.read_html('course_history.html')
#       2
#       3 for i, df in enumerate(df_list):
#       4     print(df)
#       5     df.to_csv('table {}.csv'.format(i))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, tupleize_cols, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#     985                   decimal=decimal, converters=converters, na_values=na_values,
#     986                   keep_default_na=keep_default_na,
# --> 987                   displayed_only=displayed_only)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     791     retained = None
#     792     for flav in flavor:
# --> 793         parser = _parser_dispatch(flav)
#     794         p = parser(io, compiled_match, attrs, encoding, displayed_only)
#     795
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/io/html.py in _parser_dispatch(flavor)
#     749     else:
#     750         if not _HAS_LXML:
# --> 751             raise ImportError("lxml not found, please install it")
#     752     return _valid_parsers[flavor]
#     753
#
# ImportError: lxml not found, please install it
